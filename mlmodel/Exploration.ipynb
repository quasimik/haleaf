# %% [markdown]
# ## Constants

# %%
# DATASET_PATH = 'datasets/1000sample2015.csv' # Using the small dataset for now
DATASET_PATH = 'datasets/1000sample2015.csv' # Using the small dataset for now
FEATURES_JSON_PATH = 'datasets/features-small.json'

# %% [markdown]
# ## Imports

# %%
import googleapiclient.discovery
import json
import numpy as np
import os
import pandas as pd
import pickle
import pprint as pp
from sklearn.ensemble import RandomForestClassifier
from sklearn.externals import joblib
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import FeatureUnion
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import Imputer
from fancyimpute import KNN as imputeKNN

# %% [markdown]
# ## Data cleaning

# %%
with open(FEATURES_JSON_PATH, 'r') as file:
    features_json = json.loads(file.read())

# usecols: filter to only columns we want
with open(DATASET_PATH, 'r') as file:
#     raw_data = pd.read_csv(file, dtype=np.float32, usecols=features_json.keys(), nrows=50)
    raw_data = pd.read_csv(file, dtype=np.float32, usecols=features_json.keys())

# Fill invalid values with NaNs for imputation
raw_data_new = raw_data.copy()
for title, ser in raw_data.iteritems():
    invalid_vals = []
    
    # Build invalid values to be replaced
    for option in features_json[title]["options"]:
        if not option['valid']:
            invalid_vals.append(np.float32(option['value']))
    
    # Replace invalid values
    ser_new = ser.copy()
    for i, d in ser.iteritems():
        if d in invalid_vals:
            ser_new[i] = 'NaN'
    
    # Update dataframe
    raw_data_new[title] = ser_new
raw_data = raw_data_new

# Impute NaNs with random sample from column
for title, ser in raw_data.iteritems():
    ser_sample = ser.dropna()
    ser_new = ser.copy()
    for i, d in ser.iteritems():
        if np.isnan(d):
            ser_new[i] = ser_sample.sample()
            
    raw_data_new[title] = ser_new
raw_data = raw_data_new

# Cast floats to ints
raw_data_new = raw_data.astype(np.int32) # Make it all ints
raw_data = raw_data_new

# Update datatypes
for title, ser in raw_data.iteritems():
    if features_json[title]['type'] == 'discrete':
        ser_new = ser.astype('category')
    elif features_json[title]['type'] == 'boolean':
        bool_map = {1: True, 2: False}
        ser_new = ser.map(bool_map)
        ser_new = ser_new.astype('bool')
    elif features_json[title]['type'] == 'continuous':
        ser_new = ser
        # Already np.int32
    raw_data_new[title] = ser_new
raw_data = raw_data_new

# raw_data
df = raw_data
df
# Out:
#      CVDINFR4  CHCSCNCR  CHCOCNCR  ADDEPEV2 DIABETE3 SEX _RACEGR3 _AGE_G  \
# 0       False     False     False     False        1   1        1      6
# 1       False     False     False     False        3   2        1      6
# 2       False     False     False     False        3   1        1      6
# 3       False     False     False     False        3   1        1      2
# 4       False     False      True     False        3   2        4      6
# 5       False      True     False     False        3   2        1      6
# 6        True     False     False     False        1   1        1      6
# 7        True     False     False     False        1   2        1      6
# 8       False     False      True     False        3   2        5      4
# 9       False     False     False     False        3   2        1      6
# 10      False     False     False      True        3   2        1      1
# 11      False     False     False     False        1   2        3      6
# 12      False     False     False     False        3   2        1      5
# 13      False     False     False      True        3   2        1      5
# 14      False     False     False     False        3   1        1      5
# 15      False     False      True     False        3   2        1      6
# 16      False     False     False     False        3   1        5      1
# 17       True     False     False     False        3   1        1      5
# 18      False     False     False     False        3   2        5      3
# 19      False     False     False      True        3   2        1      4
# 20       True     False     False     False        4   2        5      6
# 21      False     False     False     False        3   2        1      5
# 22      False     False      True      True        1   2        1      6
# 23      False     False     False     False        3   1        2      3
# 24      False     False     False     False        3   1        1      4
# 25      False     False     False     False        3   1        1      6
# 26      False     False     False     False        3   2        1      4
# 27      False     False     False      True        1   2        1      6
# 28      False     False     False      True        1   2        2      5
# 29      False     False     False      True        3   2        1      5
# ..        ...       ...       ...       ...      ...  ..      ...    ...
# 970      True      True      True      True        1   1        5      6
# 971     False     False     False      True        3   2        1      4
# 972     False     False     False     False        3   2        1      3
# 973     False     False     False     False        3   2        1      2
# 974     False     False     False      True        3   1        1      2
# 975     False      True     False     False        3   2        1      6
# 976     False     False     False     False        1   2        5      6
# 977     False     False     False     False        3   1        1      2
# 978     False     False     False     False        1   2        1      6
# 979     False     False     False     False        3   2        1      6
# 980     False     False     False     False        3   2        1      3
# 981     False     False     False      True        1   2        1      3
# 982     False     False     False     False        1   1        1      6
# 983     False     False     False     False        3   2        1      6
# 984     False      True      True      True        3   2        1      6
# 985     False     False     False     False        3   2        1      5
# 986     False     False     False     False        3   2        5      5
# 987     False     False     False     False        3   1        1      5
# 988      True     False     False      True        1   1        5      6
# 989     False     False     False     False        3   2        1      5
# 990     False     False     False     False        3   1        1      5
# 991     False      True      True     False        3   1        1      6
# 992     False     False      True      True        3   2        1      6
# 993      True     False     False     False        3   1        1      6
# 994     False     False      True     False        3   1        1      6
# 995      True     False     False     False        1   1        4      6
# 996     False     False      True     False        1   2        1      6
# 997     False     False      True     False        3   2        1      6
# 998     False     False     False      True        1   2        1      6
# 999     False      True      True     False        3   2        1      6
#
#      HTM4  WTKG3 _INCOMG _SMOKER3
# 0     170   9934       5        4
# 1     157   6804       3        4
# 2     173   8528       4        3
# 3     168   9752       5        3
# 4     152   7711       2        4
# 5     170   9072       5        4
# 6     178   8074       3        3
# 7     168   7484       2        4
# 8     165   8528       5        3
# 9     155   8165       3        4
# 10    168   6123       5        4
# 11    168  11793       5        4
# 12    163   9344       2        3
# 13    163   7711       5        3
# 14    170   7257       5        4
# 15    160   6350       5        3
# 16    168   7938       3        4
# 17    183   8573       5        2
# 18    157   6350       5        4
# 19    168   6804       5        3
# 20    157   5488       1        4
# 21    165   6123       5        4
# 22    170   7394       5        4
# 23    173   8165       2        1
# 24    180   7257       5        4
# 25    183   9072       5        3
# 26    173   5942       5        3
# 27    173   9072       5        4
# 28    163   8618       3        4
# 29    170   9072       5        3
# ..    ...    ...     ...      ...
# 970   170   9072       4        4
# 971   150   7257       5        4
# 972   165   8618       5        3
# 973   170   7847       5        4
# 974   180   6804       5        1
# 975   155   5625       2        4
# 976   152   7031       5        4
# 977   173   7257       5        4
# 978   155   6895       4        3
# 979   163   6123       5        4
# 980   163   5534       5        3
# 981   160  10433       5        4
# 982   180  10886       4        3
# 983   155   6350       5        4
# 984   163   3856       4        4
# 985   173   6804       4        4
# 986   152   6033       3        3
# 987   183   9616       5        4
# 988   178  11567       1        3
# 989   160   9525       5        4
# 990   168   9798       5        4
# 991   188  10206       5        4
# 992   163   5670       4        4
# 993   191   7484       5        3
# 994   178   8664       4        4
# 995   180  11294       5        1
# 996   163  13154       5        4
# 997   165   6804       5        4
# 998   163   9979       1        4
# 999   165   8165       5        4
#
# [1000 rows x 12 columns]

# %%
smoker = ((df['_SMOKER3'] == 1) | (df['_SMOKER3'] == 2) | (df['_SMOKER3'] == 3))
cancer = (df['CHCSCNCR'] | df['CHCOCNCR'])
# df[smoker & cancer].shape[0] # Count
print(df[smoker & cancer].shape[0] / df[smoker].shape[0])
print(df[~smoker & cancer].shape[0] / df[~smoker].shape[0])
# Out:
# 0.15384615384615385
# 0.1681260945709282
